# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import pandas_profiling as pandas_pf
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Ayush Pujari\AppData\Local\Temp\ipykernel_760\3299236018.py:4: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pandas_pf

# %%
df = pd.read_csv(r"C:\Users\Ayush Pujari\Downloads\advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
plt.scatter(df['TV'],df['Sales'])

# %%
plt.scatter(df['Radio'],df['Sales'])

# %%
plt.scatter(df['Newspaper'],df['Sales'])

# %%
# sklearn
# tensorflow
# pytorch
# Dl4j
# sparkML
# sparkML lib

# %%
x = df[["TV","Newspaper","Radio"]] # sklearn take by default 2D inputs thats why we need to give 2D input 
y = df.Sales

# %%
from sklearn.linear_model import LinearRegression
# from sklearn
linear = LinearRegression()

# %%
linear.fit(x,y)
# Out:
# LinearRegression()

# %%
linear.intercept_ # this is c in (mx + c)
# Out:
# 4.625124078808655

# %%
linear.coef_ # this is m in (mx + c)
# Out:
# array([0.05444578, 0.00033566, 0.10700123])

# %%
file = "liner_reg.sav" # we are just saving (y = mx + c) in this file as that would be model, if the features in the dataset increse this will incerese. 
pickle.dump(linear, open(file, "wb"))

# %%
linear.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
linear.predict([[90,80,25]]) # Y = 0.055 * 90 + 6.97 # output: 11.96
# Out:
# array([12.22712765])

# %%
l = [4,5,6,7,8,9,89,97,67,23,45]

# %%
for i in l:
    print(linear.predict([[i]]))
# Out:
# [7.19668057]
# [7.25214534]
# [7.30761011]
# [7.36307488]
# [7.41853965]
# [7.47400442]
# [11.91118606]
# [12.35490422]
# [10.69096111]
# [8.25051121]
# [9.47073616]

# %%
save_model =  pickle.load(open(file, "rb"))

# %%
save_model.predict([[45,56,90]])
# Out:
# array([16.72409158])

# %%
linear.score(x,y)
# Out:
# 0.9025912899684558

# %%
import statsmodels.formula.api as smf

# lm = smf.ols(formula="Sales ~ TV+Radio", data=df).fit()

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     912.7
# Date:                Fri, 21 Jul 2023   Prob (F-statistic):          2.39e-100
# Time:                        18:59:01   Log-Likelihood:                -383.34
# No. Observations:                 200   AIC:                             772.7
# Df Residuals:                     197   BIC:                             782.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.6309      0.290     15.952      0.000       4.058       5.203
# ...

# %%
df1 = pd.read_csv(r"C:\Users\Ayush Pujari\Downloads\dataset.csv")

# %%
data_x = df1.iloc[:,:-1]
y = df1.Target

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_x, y, test_size=0.33, random_state=40)

rand_cls = RandomForestClassifier()

# %%
type(y_test), type(df_pred['pred_value'])
# df_pred = pd.DataFrame({"pred_value": prediction})
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
rand_cls.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
prediction = rand_cls.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(prediction,y_test)
# Out:
# 0.7575342465753425

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[357,  53,  78],
#        [ 49, 101, 127],
#        [ 15,  32, 648]], dtype=int64)

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.85      0.73      0.79       488
#     Enrolled       0.54      0.36      0.44       277
#     Graduate       0.76      0.93      0.84       695
#
#     accuracy                           0.76      1460
#    macro avg       0.72      0.68      0.69      1460
# weighted avg       0.75      0.76      0.74      1460

# %%
# Type of regularization techniques.
# LASSO REgression (L1)
# Redge Regression (L2)
# Elastic Net
# difference bethween L1 and L2

# %% [markdown]
# # Project Admission Prediction, Lasso, Ridge Elastic Net

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LassoCV, RidgeCV, ElasticNetCV, LinearRegression # CV here are for cross velidation
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Ayush Pujari\Downloads\Admission_Prediction.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score            float64
# TOEFL Score          float64
# University Rating    float64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
df['GRE Score'] = df['GRE Score'].fillna(df['GRE Score'].mean())

# %%
df['TOEFL Score'] = df['TOEFL Score'].fillna(df['TOEFL Score'].mean())
df['University Rating'] = df['University Rating'].fillna(df['University Rating'].mean())

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.drop(columns=['Serial No.'], inplace=True)

# %%
# Function for all plot for the dataframe 
def plot_all(df):
    sns.boxplot(x='Research', y='Chance of Admit', data=df) # boxplot is for outliers.
    sns.swarmplot(x='Research', y='Chance of Admit', data=df) # swarmplot is for points those are there in the boxplot
    plt.show() # to show the plot

# %%
plot_all(df)

# %%
# Function for showing histograms for the dataframe with proper format
def plot_hist(df):
    df.hist(figsize=(20,20))
    plt.show()

# %%
plot_hist(df)

# %%
# Pearson's correlation graph
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap="crest", linewidths=0.4)
plt.show()

# %%
x = df.drop(columns=['Chance of Admit'])
y = df['Chance of Admit']

# %%
x
# Out:
#       GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 500, dtype: float64

# %%
scaler = StandardScaler()
arr_1 = scaler.fit_transform(x)

# %%
arr_1
# Out:
# array([[ 1.84274116e+00,  1.78854223e+00,  7.78905651e-01, ...,
#          1.09894429e+00,  1.77680627e+00,  8.86405260e-01],
#        [ 6.70814288e-01, -3.10581135e-02,  7.78905651e-01, ...,
#          1.09894429e+00,  4.85859428e-01,  8.86405260e-01],
#        [ 5.12433309e-15, -5.27312752e-01, -1.07876604e-01, ...,
#          1.73062093e-02, -9.54042814e-01,  8.86405260e-01],
#        ...,
#        [ 1.21170361e+00,  2.11937866e+00,  1.66568791e+00, ...,
#          1.63976333e+00,  1.62785086e+00,  8.86405260e-01],
#        [-4.10964364e-01, -6.92730965e-01,  7.78905651e-01, ...,
#          1.63976333e+00, -2.42366993e-01, -1.12815215e+00],
#        [ 9.41258951e-01,  9.61451165e-01,  7.78905651e-01, ...,
#          1.09894429e+00,  7.67219636e-01, -1.12815215e+00]])

# %%
df1 = pd.DataFrame(arr_1)

# %%
# Pearson's correlation graph
plt.figure(figsize=(12,8))
sns.heatmap(df1.corr(), annot=True, cmap="crest", linewidths=0.4)
plt.show()

# %%
sns.histplot(df1, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

print(arr_1.shape)

vif_score = [variance_inflation_factor(arr_1, i) for i in range(arr_1.shape[1])]
vif_column = x.columns
# Out:
# (500, 7)

# %%
vif_df = pd.DataFrame()
vif_df['vif_score'] = vif_score
vif_df['vif_column'] = vif_column

# %%
vif_df
# Out:
#    vif_score         vif_column
# 0   4.153268          GRE Score
# 1   3.792866        TOEFL Score
# 2   2.508768  University Rating
# 3   2.775750                SOP
# 4   2.037308                LOR
# 5   4.651670               CGPA
# 6   1.459311           Research

# %%
X_train, X_test, y_train, y_test = train_test_split(arr_1, y, test_size=0.33, random_state=40)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import pickle

pickle.dump(lr, open("model.pkl", "wb"))

# %%
model = pickle.load(open("model.pkl", "rb"))

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
model.score(X_test , y_test)
# Out:
# 0.8188502610537732

# %%
model.coef_
# Out:
# array([0.02468296, 0.02200222, 0.00603684, 0.004386  , 0.01387429,
#        0.06439334, 0.00818531])

# %%
model.intercept_
# Out:
# 0.7216673061066343

# %%
lassocv = LassoCV(cv=20, max_iter=200000, alphas=None, random_state=42, n_jobs=-1)
lassocv.fit(X_train, y_train)
# Out:
# LassoCV(cv=20, max_iter=200000, n_jobs=-1, random_state=42)

# %%
lassocv.alpha_
# Out:
# 0.00031920477966477834

# %%
lasso = Lasso(alpha=lassocv.alpha_)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.00031920477966477834)

# %%
lasso.score(X_test, y_test)
# Out:
# 0.8186841297064488

# %%
ridgecv = RidgeCV(alphas=np.random.uniform(0,10,50), cv=50)
ridgecv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([5.49993158, 4.40294825, 9.03451427, 0.32366878, 3.639331  ,
#        2.57584553, 7.40676609, 8.92037328, 4.24260028, 9.85928566,
#        4.7477589 , 2.48055454, 4.72920647, 1.94350331, 9.12003986,
#        5.32599696, 3.01587381, 4.86735046, 7.15921368, 6.43735172,
#        1.18470827, 6.79951807, 4.01661477, 2.81684446, 7.65159231,
#        0.2743552 , 8.1419211 , 0.48919543, 2.04996696, 6.59580916,
#        3.71343697, 6.84420344, 8.3279719 , 3.8208473 , 6.9984991 ,
#        5.17438304, 2.1236993 , 3.01190526, 1.40948403, 6.92435933,
#        8.10026855, 2.75482689, 1.30861148, 7.29540747, 9.1409335 ,
#        1.70929817, 5.36378523, 4.93944219, 7.28271755, 4.78552433]),
#         cv=50)

# %%
ridgecv.alpha_
# Out:
# 9.859285664256364

# %%
ridgecv.score(X_test, y_test)
# Out:
# 0.8158652079292548

# %%
ridge = Ridge(alpha=ridgecv.alpha_, random_state=22)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=9.859285664256364, random_state=22)

# %%
ridge.score(X_test, y_test)
# Out:
# 0.8158652079292548

# %%
elasticcv = ElasticNetCV(alphas=None, cv=50)

# %%
elasticcv.fit(X_train, y_train)
# Out:
# ElasticNetCV(cv=50)

# %%
elasticcv.alpha_
# Out:
# 0.00024035710093184485

# %%
elasticcv.l1_ratio_
# Out:
# 0.5

# %%
elastic = ElasticNet(alpha=elasticcv.alpha_, l1_ratio=elasticcv.l1_ratio_)
elastic.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.00024035710093184485)

# %%
elastic.score(X_test, y_test)
# Out:
# 0.8187805250193647
